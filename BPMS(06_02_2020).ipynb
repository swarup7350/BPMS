# %% [markdown]
# <a href="https://colab.research.google.com/github/swarup7350/BPMS/blob/master/BPMS(06_02_2020).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import pie, axis, show
# %matplotlib inline                                                              

import warnings
warnings.filterwarnings('ignore') 
pd.set_option('display.max_columns', 100)

# %% [markdown]
# **ULB Master File Uplode**

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#2. Get ULB Master file From Drive
downloaded = drive.CreateFile({'id':'1Vk1NDCSkQzb7JC8ATaJr56F-f5UudS3y'}) # replace the id with id of file you want to access
downloaded.GetContentFile('ULBTypeMaster.csv')

#3. Read file From Drive as panda dataframe
import pandas as pd
ulbm = pd.read_csv('ULBTypeMaster.csv')

# %%
ulbm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 6 columns):
# Sr.No.       241 non-null int64
# Region       241 non-null object
# District     241 non-null object
# ULB Name     241 non-null object
# ULB Type     241 non-null object
# Live ULB     241 non-null object
# dtypes: int64(1), object(5)
# memory usage: 11.4+ KB

# %% [markdown]
# **ULB Pending Praposal File Upload**

# %%
# Get ULB Praposal file From Drive
downloaded = drive.CreateFile({'id':'1eVtySuabe0k-s9zXJz30j6GdjqUpG-Xj'})
downloaded.GetContentFile('Book2(ULB).csv')

# Read file From Drive as panda dataframe
import pandas as pd
ulb1 = pd.read_csv('Book2(ULB).csv')

# %%
ulb1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6579 entries, 0 to 6578
# Data columns (total 17 columns):
# Sr No.                       6579 non-null int64
# Region                       6579 non-null object
# District                     6579 non-null object
# ULB Name                     6579 non-null object
# Proposal Code                6579 non-null object
# Risk Base                    6579 non-null object
# Government Scheme            158 non-null object
# Service Name                 6579 non-null object
# Owner Name                   6579 non-null object
# Site Address                 5058 non-null object
# Technical Person Name        6576 non-null object
# Technical Person Category    6576 non-null object
# Pending By                   6573 non-null object
# Designation                  6573 non-null object
# Registration Date            6579 non-null object
# Days                         6579 non-null int64
# Reasons                      6579 non-null object
# ...

# %%
ulb1.rename(columns = {'Sr No.':'Sr No.', 'Reasons':'Reasons', 
                              'Application Received Date':'Registration Date'}, inplace = True)

# %%
ulb1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6579 entries, 0 to 6578
# Data columns (total 17 columns):
# Sr No.                       6579 non-null int64
# Region                       6579 non-null object
# District                     6579 non-null object
# ULB Name                     6579 non-null object
# Proposal Code                6579 non-null object
# Risk Base                    6579 non-null object
# Government Scheme            158 non-null object
# Service Name                 6579 non-null object
# Owner Name                   6579 non-null object
# Site Address                 5058 non-null object
# Technical Person Name        6576 non-null object
# Technical Person Category    6576 non-null object
# Pending By                   6573 non-null object
# Designation                  6573 non-null object
# Registration Date            6579 non-null object
# Days                         6579 non-null int64
# Reasons                      6579 non-null object
# ...

# %% [markdown]
# **Tech Pending Praposal File Upload**

# %%
# Get Tech Praposal file From Drive
downloaded = drive.CreateFile({'id':'1tQffaCcCR0I3M6OvDe8WobNO3FMofkSE'})
downloaded.GetContentFile('Book1(Tech).csv')

# Read file From Drive as panda dataframe
import pandas as pd
Tech = pd.read_csv('Book1(Tech).csv')

# %%
Tech.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6996 entries, 0 to 6995
# Data columns (total 15 columns):
# Sr No.                       6996 non-null int64
# Region                       6996 non-null object
# District                     6996 non-null object
# ULB Name                     6996 non-null object
# Proposal Code                6996 non-null object
# Risk Base                    6996 non-null object
# Government Scheme            119 non-null object
# Service Name                 6996 non-null object
# Owner Name                   6996 non-null object
# Site Address                 6499 non-null object
# Technical Person Name        6992 non-null object
# Technical Person Category    6991 non-null object
# Application Received Date    6996 non-null object
# Days                         6996 non-null int64
# Reasons                      6996 non-null object
# dtypes: int64(2), object(13)
# memory usage: 820.0+ KB

# %% [markdown]
# **Architect Tech Pending Praposal File Upload**

# %%
# Get Tech Praposal by architect file From Drive
downloaded = drive.CreateFile({'id':'1F3PV02HWVwHyTPFBa0PWp4lwPVEE1vC9'})
downloaded.GetContentFile('TechnicallicenseregistrationFromArchitect.csv')

# Read file From Drive as panda dataframe
import pandas as pd
TechArchi = pd.read_csv('TechnicallicenseregistrationFromArchitect.csv')

# %%
TechArchi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1471 entries, 0 to 1470
# Data columns (total 9 columns):
# Sr No                        1471 non-null int64
# Region                       1471 non-null object
# District                     1471 non-null object
# ULB Name                     1471 non-null object
# Technical Person Name        1471 non-null object
# Technical Person Category    1468 non-null object
# Registration Date            1471 non-null object
# Days                         1471 non-null int64
# Reason                       1471 non-null object
# dtypes: int64(2), object(7)
# memory usage: 103.6+ KB

# %% [markdown]
# **ULB Tech Pending Praposal File Upload**

# %%
# Get Tech Praposal by ULB file From Drive
downloaded = drive.CreateFile({'id':'13LZgXnRK34bMqufKJOt2DrFVnVBN8CdS'})
downloaded.GetContentFile('TechnicallicenseregistrationFromULB.csv')

# Read file From Drive as panda dataframe
import pandas as pd
ULBArchi = pd.read_csv('TechnicallicenseregistrationFromULB.csv')

# %%
ULBArchi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3074 entries, 0 to 3073
# Data columns (total 11 columns):
# Sr No                        3074 non-null int64
# Region                       3074 non-null object
# District                     3074 non-null object
# ULB Name                     3074 non-null object
# Technical Person Name        3074 non-null object
# Technical Person Category    3068 non-null object
# Pending From Name            3072 non-null object
# Designation                  3072 non-null object
# Registration Date            3074 non-null object
# Days                         3074 non-null int64
# Reason                       3074 non-null object
# dtypes: int64(2), object(9)
# memory usage: 264.3+ KB

# %%
ULBArchi.rename(columns = {'Sr No':'Sr No.', 'Reason':'Reasons', 'Pending From Name':'Pending By'}, inplace = True)
ULBArchi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3074 entries, 0 to 3073
# Data columns (total 11 columns):
# Sr No.                       3074 non-null int64
# Region                       3074 non-null object
# District                     3074 non-null object
# ULB Name                     3074 non-null object
# Technical Person Name        3074 non-null object
# Technical Person Category    3068 non-null object
# Pending By                   3072 non-null object
# Designation                  3072 non-null object
# Registration Date            3074 non-null object
# Days                         3074 non-null int64
# Reasons                      3074 non-null object
# dtypes: int64(2), object(9)
# memory usage: 264.3+ KB

# %%
ulb1.append(ULBArchi)
ulb1.head()
# Out:
#    Sr No.    Region District                     ULB Name       Proposal Code  \
# 0       1  Amravati    Akola  Akola Municipal Corporation  RYBE-DDMCK-18-0002
# 1       2  Amravati    Akola  Akola Municipal Corporation  JMHH-DDMCK-18-0007
# 2       3  Amravati    Akola  Akola Municipal Corporation  VZEU-DDMCK-18-0008
# 3       4  Amravati    Akola  Akola Municipal Corporation  RYBE-DDMCK-18-0012
# 4       5  Amravati    Akola  Akola Municipal Corporation  VZEU-DDMCK-18-0012
#
#              Risk Base Government Scheme         Service Name  \
# 0  Building Permission               NaN  Building Permission
# 1  Building Permission               NaN  Building Permission
# 2  Building Permission               NaN  Building Permission
# 3  Building Permission               NaN  Building Permission
# 4  Building Permission               NaN  Building Permission
#
#                      Owner Name                        Site Address  \
# ...

# %%
#To know Column Name 
for col in ulb1.columns:
   print(col)
# Out:
# Sr No.
# Region
# District
# ULB Name
# Proposal Code
# Risk Base
# Government Scheme
# Service Name
# Owner Name
# Site Address
# Technical Person Name
# Technical Person Category
# Pending By
# Designation
# Registration Date
# Days
# Reasons

# %%
mearge = pd.merge(ulbm,
                 ulb1[['District', 'ULB Name', 'Proposal Code', 'Service Name', 'Application Received Date', 'Days', 'Reasons']],
                 on=['District', 'ULB Name'],
                 how='left', indicator=True)

mearge.head()
# Out:
#    Sr.No.    Region District                     ULB Name ULB Type Live ULB   \
# 0       1  Amravati    Akola  Akola Municipal Corporation        D         Y
# 1       1  Amravati    Akola  Akola Municipal Corporation        D         Y
# 2       1  Amravati    Akola  Akola Municipal Corporation        D         Y
# 3       1  Amravati    Akola  Akola Municipal Corporation        D         Y
# 4       1  Amravati    Akola  Akola Municipal Corporation        D         Y
#
#         Proposal Code         Service Name Application Received Date   Days  \
# 0  RYBE-DDMCK-18-0002  Building Permission                24-11-2018  396.0
# 1  JMHH-DDMCK-18-0007  Building Permission                22-12-2019    6.0
# 2  VZEU-DDMCK-18-0008  Building Permission                17-02-2019  345.0
# 3  RYBE-DDMCK-18-0012  Building Permission                17-12-2018  235.0
# 4  VZEU-DDMCK-18-0012  Building Permission                22-02-2019  346.0
#
#                          Reasons _merge
# ...

# %%
pd.pivot_table(mearge,index=["ULB Name","Service Name"],values=["Proposal Code"],
               columns=["Reasons"],aggfunc=[len],fill_value=0,margins=True)
# Out:
#                                                                           len  \
#                                                                 Proposal Code
# Reasons                                                     Authority pending
# ULB Name                         Service Name
# Achalpur Municipal Council       Building Permission                        0
# Ahmednagar Municipal Corporation Building Permission                        0
#                                  Part Occupancy                             0
#                                  Plinth Permission                         22
#                                  Revise Building Permission                 0
# ...                                                                       ...
# Yeola Municipal Council          Building Permission                        0
#                                  Full Occupancy                             2
# ...

# %%
mearge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6590 entries, 0 to 6589
# Data columns (total 12 columns):
# Sr.No.                       6590 non-null int64
# Region                       6590 non-null object
# District                     6590 non-null object
# ULB Name                     6590 non-null object
# ULB Type                     6590 non-null object
# Live ULB                     6590 non-null object
# Proposal Code                6579 non-null object
# Service Name                 6579 non-null object
# Application Received Date    6579 non-null object
# Days                         6579 non-null float64
# Reasons                      6579 non-null object
# _merge                       6590 non-null category
# dtypes: category(1), float64(1), int64(1), object(9)
# memory usage: 624.3+ KB

# %% [markdown]
# #**Concat Files**
#
# ( by columans )

# %%
frames = [ulb1, ULBArchi]
result1 = pd.concat(frames)
result1
# Out:
#       Days             Designation District Government Scheme  \
# 0      396  Municipal Commissioner    Akola               NaN
# 1        6            Town Planner    Akola               NaN
# 2      345         Junior Engineer    Akola               NaN
# 3      235  Municipal Commissioner    Akola               NaN
# 4      346  Assistant Town Planner    Akola               NaN
# ...    ...                     ...      ...               ...
# 3069    16                Surveyor  Solapur               NaN
# 3070   628                Surveyor  Solapur               NaN
# 3071     3                Surveyor  Solapur               NaN
# 3072    21                Surveyor  Solapur               NaN
# 3073    12                Surveyor  Solapur               NaN
#
#                         Owner Name              Pending By  \
# 0                   PRADIP B GAWAI     Mr. Sanjay Kapadnis
# 1         Shri Anil Pundlik Nawkar   TP Mr. Uday Taralekar
# ...

# %%
frames = [ulb1, ULBArchi]
result1 = pd.concat(frames)
result1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9653 entries, 0 to 3073
# Data columns (total 21 columns):
# Application Received Date    6579 non-null object
# Days                         9653 non-null int64
# Designation                  9645 non-null object
# District                     9653 non-null object
# Government Scheme            158 non-null object
# Owner Name                   6579 non-null object
# Pending By                   6573 non-null object
# Pending From Name            3072 non-null object
# Proposal Code                6579 non-null object
# Reason                       3074 non-null object
# Reasons                      6579 non-null object
# Region                       9653 non-null object
# Registration Date            3074 non-null object
# Risk Base                    6579 non-null object
# Service Name                 6579 non-null object
# Site Address                 5058 non-null object
# Sr No                        3074 non-null float64
# ...

# %%
#ulb1.groupby('ULB Name')['Proposal Code'].count()

# %%
#ulb1.groupby('Region')['Proposal Code'].count()

# %%
#pd.crosstab(ulbm['Region'],ulbm['ULB Type'])

# %%
#ulb1.merge(ULBArchi, left_on='Region', right_on='Region', how='outer')
