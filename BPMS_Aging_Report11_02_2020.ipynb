# %% [markdown]
# <a href="https://colab.research.google.com/github/swarup7350/BPMS/blob/master/BPMS_Aging_Report11_02_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import pie, axis, show
# %matplotlib inline                                                              

import warnings
warnings.filterwarnings('ignore') 
pd.set_option('display.max_columns', 100)

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#Uploading ULB Master File
downloaded = drive.CreateFile({'id':'1Vk1NDCSkQzb7JC8ATaJr56F-f5UudS3y'}) # replace the id with id of file you want to access
downloaded.GetContentFile('ULBTypeMaster.csv')
import pandas as pd
ulbm = pd.read_csv('ULBTypeMaster.csv')
ulbm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 6 columns):
# Sr.No.       241 non-null int64
# Region       241 non-null object
# District     241 non-null object
# ULB Name     241 non-null object
# ULB Type     241 non-null object
# Live ULB     241 non-null object
# dtypes: int64(1), object(5)
# memory usage: 11.4+ KB

# %%
ulbm.rename(columns = {'Sr.No.':'Sr No'}, inplace = True)
ulbm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 6 columns):
# Sr No        241 non-null int64
# Region       241 non-null object
# District     241 non-null object
# ULB Name     241 non-null object
# ULB Type     241 non-null object
# Live ULB     241 non-null object
# dtypes: int64(1), object(5)
# memory usage: 11.4+ KB

# %%
#Uploading Praposal list pending From ULB
downloaded = drive.CreateFile({'id':'1eVtySuabe0k-s9zXJz30j6GdjqUpG-Xj'})
downloaded.GetContentFile('Book2(ULB).csv')
import pandas as pd
ulb1 = pd.read_csv('Book2(ULB).csv')
ulb1.info()
ulb1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6579 entries, 0 to 6578
# Data columns (total 17 columns):
# Sr No.                       6579 non-null int64
# Region                       6579 non-null object
# District                     6579 non-null object
# ULB Name                     6579 non-null object
# Proposal Code                6579 non-null object
# Risk Base                    6579 non-null object
# Government Scheme            158 non-null object
# Service Name                 6579 non-null object
# Owner Name                   6579 non-null object
# Site Address                 5058 non-null object
# Technical Person Name        6576 non-null object
# Technical Person Category    6576 non-null object
# Pending By                   6573 non-null object
# Designation                  6573 non-null object
# Application Received Date    6579 non-null object
# Days                         6579 non-null int64
# Reasons                      6579 non-null object
# dtypes: int64(2), object(15)
# memory usage: 873.9+ KB
#       Sr No.    Region District                     ULB Name  \
# 0          1  Amravati    Akola  Akola Municipal Corporation
# 1          2  Amravati    Akola  Akola Municipal Corporation
# 2          3  Amravati    Akola  Akola Municipal Corporation
# 3          4  Amravati    Akola  Akola Municipal Corporation
# 4          5  Amravati    Akola  Akola Municipal Corporation
# ...      ...       ...      ...                          ...
# 6574    6575      Pune  Solapur    Sangola Municipal Council
# 6575    6576      Pune  Solapur    Sangola Municipal Council
# 6576    6577      Pune  Solapur    Sangola Municipal Council
# 6577    6578      Pune  Solapur    Sangola Municipal Council
# 6578    6579      Pune  Solapur    Sangola Municipal Council
#
#            Proposal Code                                          Risk Base  \
# 0     RYBE-DDMCK-18-0002                                Building Permission
# 1     JMHH-DDMCK-18-0007                                Building Permission
# 2     VZEU-DDMCK-18-0008                                Building Permission
# 3     RYBE-DDMCK-18-0012                                Building Permission
# 4     VZEU-DDMCK-18-0012                                Building Permission
# ...                  ...                                                ...
# 6574  ZICY-CCSSC-19-0002                                Building Permission
# 6575  SBGP-CCSSC-19-0001  Moderate Risk Based Building Permission (From ...
# 6576  UNGK-CCSSC-19-0002                                Building Permission
# 6577  ZICY-CCSSC-19-0006                                Building Permission
# 6578  YOBK-CCSSC-19-0031                                Building Permission
#
#      Government Scheme         Service Name                    Owner Name  \
# 0                  NaN  Building Permission                PRADIP B GAWAI
# 1                  NaN  Building Permission      Shri Anil Pundlik Nawkar
# 2                  NaN  Building Permission     MADHAV RAMKRISHNA BHAKARE
# 3                  NaN  Building Permission                  RUCHA D MULE
# 4                  NaN  Building Permission  PRATIBHA MADHUKAR SONGAONKAR
# ...                ...                  ...                           ...
# 6574               NaN       Full Occupancy    VIKRANT BHALCHANDRA KAMBLE
# 6575               NaN    Plinth Permission      SARIKA KRUSHNADEV SHINDE
# 6576               NaN    Plinth Permission       Ramdas Dhondiba Bhosale
# 6577               NaN    Plinth Permission  SHRIKRISHNA TANAJI WAGHAMARE
# 6578               NaN    Plinth Permission          SAMBHAJI LAXMAN BILE
#
#                             Site Address          Technical Person Name  \
# 0                          KHADKI, AKOLA              Shrikant Dhanokar
# 1     Palhade Layout, Mothi Umari, Akola                  Omnath Pathak
# 2                    UNNATI NAGAR,AKOLA.                 Dinesh Thakare
# 3                         MALKAPUR AKOLA              Shrikant Dhanokar
# 4                           UMARI,AKOLA.                 Dinesh Thakare
# ...                                  ...                            ...
# 6574                                 NaN           Akash Bhaskar Mhetre
# 6575                                 NaN        Manoj Mahaling Ghongade
# 6576                                 NaN    Sanjaykumar Vasantrao Dighe
# 6577                                 NaN           Akash Bhaskar Mhetre
# 6578                                 NaN  Ashishkumar Vitthalrao Shinde
#
#      Technical Person Category              Pending By  \
# 0                    Architect     Mr. Sanjay Kapadnis
# 1               Civil Engineer   TP Mr. Uday Taralekar
# 2                 Supervisor 1  Shri. Laxmikant Bangar
# 3                    Architect     Mr. Sanjay Kapadnis
# 4                 Supervisor 1     Shri Sandip Gawande
# ...                        ...                     ...
# 6574            Civil Engineer         Samadhan Shinde
# 6575            Civil Engineer          Kailash Kendre
# 6576            Civil Engineer         Samadhan Shinde
# 6577            Civil Engineer         Samadhan Shinde
# 6578            Civil Engineer         Samadhan Shinde
#
#                  Designation Application Received Date  Days  \
# 0     Municipal Commissioner                24-11-2018   396
# 1               Town Planner                22-12-2019     6
# 2            Junior Engineer                17-02-2019   345
# 3     Municipal Commissioner                17-12-2018   235
# 4     Assistant Town Planner                22-02-2019   346
# ...                      ...                       ...   ...
# 6574          Civil Engineer                30-01-2020     4
# 6575           Chief Officer                29-01-2020     5
# 6576          Civil Engineer                07-01-2020    27
# 6577          Civil Engineer                16-01-2020   135
# 6578          Civil Engineer                24-01-2020    10
#
#                             Reasons
# 0                  Pending from ULB
# 1                  Pending from ULB
# 2                  Pending from ULB
# 3     Document Verification Pending
# 4           Site Inspection Pending
# ...                             ...
# 6574  Document Verification Pending
# 6575  Document Verification Pending
# 6576              Authority pending
# 6577              Authority pending
# 6578  Document Verification Pending
#
# [6579 rows x 17 columns]

# %%
ulb1.rename(columns = {'Service Name':'Service_Name', 'Application Received Date':'Registration Date', 'Reasons':'Reason',
                       'Sr No.':'Sr No', 'Pending By':'Pending From Name'}, inplace = True)
ulb1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6579 entries, 0 to 6578
# Data columns (total 17 columns):
# Sr No                        6579 non-null int64
# Region                       6579 non-null object
# District                     6579 non-null object
# ULB Name                     6579 non-null object
# Proposal Code                6579 non-null object
# Risk Base                    6579 non-null object
# Government Scheme            158 non-null object
# Service_Name                 6579 non-null object
# Owner Name                   6579 non-null object
# Site Address                 5058 non-null object
# Technical Person Name        6576 non-null object
# Technical Person Category    6576 non-null object
# Pending From Name            6573 non-null object
# Designation                  6573 non-null object
# Registration Date            6579 non-null object
# Days                         6579 non-null int64
# Reason                       6579 non-null object
# dtypes: int64(2), object(15)
# memory usage: 873.9+ KB

# %%
# Uploding Technical license registrations From ULB Praposal file
downloaded = drive.CreateFile({'id':'13LZgXnRK34bMqufKJOt2DrFVnVBN8CdS'}) #https://drive.google.com/open?id=13LZgXnRK34bMqufKJOt2DrFVnVBN8CdS
downloaded.GetContentFile('TechnicallicenseregistrationFromULB.csv')
import pandas as pd
Techliregiulb = pd.read_csv('TechnicallicenseregistrationFromULB.csv')

# %%
#Techliregiulb.insert(loc=7)
Techliregiulb=Techliregiulb.assign(Service_Name='Technical License Registration')[['Service_Name'] + Techliregiulb.columns.tolist()]
Techliregiulb.info()
Techliregiulb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3074 entries, 0 to 3073
# Data columns (total 12 columns):
# Service_Name                 3074 non-null object
# Sr No                        3074 non-null int64
# Region                       3074 non-null object
# District                     3074 non-null object
# ULB Name                     3074 non-null object
# Technical Person Name        3074 non-null object
# Technical Person Category    3068 non-null object
# Pending From Name            3072 non-null object
# Designation                  3072 non-null object
# Registration Date            3074 non-null object
# Days                         3074 non-null int64
# Reason                       3074 non-null object
# dtypes: int64(2), object(10)
# memory usage: 288.3+ KB
#                         Service_Name  Sr No    Region District  \
# 0     Technical License Registration      1  Amravati    Akola
# 1     Technical License Registration      2  Amravati    Akola
# 2     Technical License Registration      3  Amravati    Akola
# 3     Technical License Registration      4  Amravati    Akola
# 4     Technical License Registration      5  Amravati    Akola
# ...                              ...    ...       ...      ...
# 3069  Technical License Registration   3070      Pune  Solapur
# 3070  Technical License Registration   3071      Pune  Solapur
# 3071  Technical License Registration   3072      Pune  Solapur
# 3072  Technical License Registration   3073      Pune  Solapur
# 3073  Technical License Registration   3074      Pune  Solapur
#
#                            ULB Name Technical Person Name  \
# 0       Akola Municipal Corporation      Prashant Kothari
# 1       Akola Municipal Corporation       shivanand bhise
# 2       Akola Municipal Corporation          Vishal Tadas
# 3       Akola Municipal Corporation        Manish Gawande
# 4       Akola Municipal Corporation       Pradip  Pejgude
# ...                             ...                   ...
# 3069  Solapur Municipal Corporation      Prabhakar Myadam
# 3070  Solapur Municipal Corporation         Vishal Nalwar
# 3071  Solapur Municipal Corporation            ANIL PATIL
# 3072  Solapur Municipal Corporation           ATUL PRABHU
# 3073  Solapur Municipal Corporation  RIYAZ AHMED KOTKUNDE
#
#      Technical Person Category  Pending From Name Designation  \
# 0               Civil Engineer  Rajendra Deshmukh       Clerk
# 1                 Supervisor 2  Rajendra Deshmukh       Clerk
# 2               Civil Engineer  Rajendra Deshmukh       Clerk
# 3                 Supervisor 1  Rajendra Deshmukh       Clerk
# 4          Structural Engineer  Rajendra Deshmukh       Clerk
# ...                        ...                ...         ...
# 3069              Supervisor 2         ASHU GHULE    Surveyor
# 3070       Structural Engineer         ASHU GHULE    Surveyor
# 3071            Civil Engineer         ASHU GHULE    Surveyor
# 3072                 Architect         ASHU GHULE    Surveyor
# 3073            Civil Engineer         ASHU GHULE    Surveyor
#
#      Registration Date  Days                         Reason
# 0           24-01-2020    10              Authority Pending
# 1           06-01-2020    28              Authority Pending
# 2           13-01-2020    21              Authority Pending
# 3           03-01-2019   396              Authority Pending
# 4           30-09-2019   126              Authority Pending
# ...                ...   ...                            ...
# 3069        18-01-2020    16  Document verification Pending
# 3070        16-05-2018   628  Document verification Pending
# 3071        31-01-2020     3  Document verification Pending
# 3072        13-01-2020    21  Document verification Pending
# 3073        22-01-2020    12  Document verification Pending
#
# [3074 rows x 12 columns]

# %%
frames = [ulb1, Techliregiulb]
Pendingfromulb = pd.concat(frames)
Pendingfromulb.info()
Pendingfromulb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9653 entries, 0 to 3073
# Data columns (total 17 columns):
# Days                         9653 non-null int64
# Designation                  9645 non-null object
# District                     9653 non-null object
# Government Scheme            158 non-null object
# Owner Name                   6579 non-null object
# Pending From Name            9645 non-null object
# Proposal Code                6579 non-null object
# Reason                       9653 non-null object
# Region                       9653 non-null object
# Registration Date            9653 non-null object
# Risk Base                    6579 non-null object
# Service_Name                 9653 non-null object
# Site Address                 5058 non-null object
# Sr No                        9653 non-null int64
# Technical Person Category    9644 non-null object
# Technical Person Name        9650 non-null object
# ULB Name                     9653 non-null object
# dtypes: int64(2), object(15)
# memory usage: 1.3+ MB
#       Days             Designation District Government Scheme  \
# 0      396  Municipal Commissioner    Akola               NaN
# 1        6            Town Planner    Akola               NaN
# 2      345         Junior Engineer    Akola               NaN
# 3      235  Municipal Commissioner    Akola               NaN
# 4      346  Assistant Town Planner    Akola               NaN
# ...    ...                     ...      ...               ...
# 3069    16                Surveyor  Solapur               NaN
# 3070   628                Surveyor  Solapur               NaN
# 3071     3                Surveyor  Solapur               NaN
# 3072    21                Surveyor  Solapur               NaN
# 3073    12                Surveyor  Solapur               NaN
#
#                         Owner Name       Pending From Name  \
# 0                   PRADIP B GAWAI     Mr. Sanjay Kapadnis
# 1         Shri Anil Pundlik Nawkar   TP Mr. Uday Taralekar
# 2        MADHAV RAMKRISHNA BHAKARE  Shri. Laxmikant Bangar
# 3                     RUCHA D MULE     Mr. Sanjay Kapadnis
# 4     PRATIBHA MADHUKAR SONGAONKAR     Shri Sandip Gawande
# ...                            ...                     ...
# 3069                           NaN              ASHU GHULE
# 3070                           NaN              ASHU GHULE
# 3071                           NaN              ASHU GHULE
# 3072                           NaN              ASHU GHULE
# 3073                           NaN              ASHU GHULE
#
#            Proposal Code                         Reason    Region  \
# 0     RYBE-DDMCK-18-0002               Pending from ULB  Amravati
# 1     JMHH-DDMCK-18-0007               Pending from ULB  Amravati
# 2     VZEU-DDMCK-18-0008               Pending from ULB  Amravati
# 3     RYBE-DDMCK-18-0012  Document Verification Pending  Amravati
# 4     VZEU-DDMCK-18-0012        Site Inspection Pending  Amravati
# ...                  ...                            ...       ...
# 3069                 NaN  Document verification Pending      Pune
# 3070                 NaN  Document verification Pending      Pune
# 3071                 NaN  Document verification Pending      Pune
# 3072                 NaN  Document verification Pending      Pune
# 3073                 NaN  Document verification Pending      Pune
#
#      Registration Date            Risk Base                    Service_Name  \
# 0           24-11-2018  Building Permission             Building Permission
# 1           22-12-2019  Building Permission             Building Permission
# 2           17-02-2019  Building Permission             Building Permission
# 3           17-12-2018  Building Permission             Building Permission
# 4           22-02-2019  Building Permission             Building Permission
# ...                ...                  ...                             ...
# 3069        18-01-2020                  NaN  Technical License Registration
# 3070        16-05-2018                  NaN  Technical License Registration
# 3071        31-01-2020                  NaN  Technical License Registration
# 3072        13-01-2020                  NaN  Technical License Registration
# 3073        22-01-2020                  NaN  Technical License Registration
#
#                             Site Address  Sr No Technical Person Category  \
# 0                          KHADKI, AKOLA      1                 Architect
# 1     Palhade Layout, Mothi Umari, Akola      2            Civil Engineer
# 2                    UNNATI NAGAR,AKOLA.      3              Supervisor 1
# 3                         MALKAPUR AKOLA      4                 Architect
# 4                           UMARI,AKOLA.      5              Supervisor 1
# ...                                  ...    ...                       ...
# 3069                                 NaN   3070              Supervisor 2
# 3070                                 NaN   3071       Structural Engineer
# 3071                                 NaN   3072            Civil Engineer
# 3072                                 NaN   3073                 Architect
# 3073                                 NaN   3074            Civil Engineer
#
#      Technical Person Name                       ULB Name
# 0        Shrikant Dhanokar    Akola Municipal Corporation
# 1            Omnath Pathak    Akola Municipal Corporation
# 2           Dinesh Thakare    Akola Municipal Corporation
# 3        Shrikant Dhanokar    Akola Municipal Corporation
# 4           Dinesh Thakare    Akola Municipal Corporation
# ...                    ...                            ...
# 3069      Prabhakar Myadam  Solapur Municipal Corporation
# 3070         Vishal Nalwar  Solapur Municipal Corporation
# 3071            ANIL PATIL  Solapur Municipal Corporation
# 3072           ATUL PRABHU  Solapur Municipal Corporation
# 3073  RIYAZ AHMED KOTKUNDE  Solapur Municipal Corporation
#
# [9653 rows x 17 columns]

# %%
frames = [ulbm, Pendingfromulb]
OP = pd.concat(frames)
OP.info()
OP
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9894 entries, 0 to 3073
# Data columns (total 19 columns):
# Days                         9653 non-null float64
# Designation                  9645 non-null object
# District                     9894 non-null object
# Government Scheme            158 non-null object
# Live ULB                     241 non-null object
# Owner Name                   6579 non-null object
# Pending From Name            9645 non-null object
# Proposal Code                6579 non-null object
# Reason                       9653 non-null object
# Region                       9894 non-null object
# Registration Date            9653 non-null object
# Risk Base                    6579 non-null object
# Service_Name                 9653 non-null object
# Site Address                 5058 non-null object
# Sr No                        9894 non-null int64
# Technical Person Category    9644 non-null object
# Technical Person Name        9650 non-null object
# ULB Name                     9894 non-null object
# ULB Type                     241 non-null object
# dtypes: float64(1), int64(1), object(17)
# memory usage: 1.5+ MB
#        Days Designation District Government Scheme Live ULB  Owner Name  \
# 0       NaN         NaN    Akola               NaN         Y        NaN
# 1       NaN         NaN    Akola               NaN         Y        NaN
# 2       NaN         NaN    Akola               NaN         Y        NaN
# 3       NaN         NaN    Akola               NaN         Y        NaN
# 4       NaN         NaN    Akola               NaN         Y        NaN
# ...     ...         ...      ...               ...       ...        ...
# 3069   16.0    Surveyor  Solapur               NaN       NaN        NaN
# 3070  628.0    Surveyor  Solapur               NaN       NaN        NaN
# 3071    3.0    Surveyor  Solapur               NaN       NaN        NaN
# 3072   21.0    Surveyor  Solapur               NaN       NaN        NaN
# 3073   12.0    Surveyor  Solapur               NaN       NaN        NaN
#
#      Pending From Name Proposal Code                         Reason    Region  \
# 0                  NaN           NaN                            NaN  Amravati
# 1                  NaN           NaN                            NaN  Amravati
# 2                  NaN           NaN                            NaN  Amravati
# 3                  NaN           NaN                            NaN  Amravati
# 4                  NaN           NaN                            NaN  Amravati
# ...                ...           ...                            ...       ...
# 3069        ASHU GHULE           NaN  Document verification Pending      Pune
# 3070        ASHU GHULE           NaN  Document verification Pending      Pune
# 3071        ASHU GHULE           NaN  Document verification Pending      Pune
# 3072        ASHU GHULE           NaN  Document verification Pending      Pune
# 3073        ASHU GHULE           NaN  Document verification Pending      Pune
#
#      Registration Date Risk Base                    Service_Name Site Address  \
# 0                  NaN       NaN                             NaN          NaN
# 1                  NaN       NaN                             NaN          NaN
# 2                  NaN       NaN                             NaN          NaN
# 3                  NaN       NaN                             NaN          NaN
# 4                  NaN       NaN                             NaN          NaN
# ...                ...       ...                             ...          ...
# 3069        18-01-2020       NaN  Technical License Registration          NaN
# 3070        16-05-2018       NaN  Technical License Registration          NaN
# 3071        31-01-2020       NaN  Technical License Registration          NaN
# 3072        13-01-2020       NaN  Technical License Registration          NaN
# 3073        22-01-2020       NaN  Technical License Registration          NaN
#
#       Sr No Technical Person Category Technical Person Name  \
# 0         1                       NaN                   NaN
# 1         2                       NaN                   NaN
# 2         3                       NaN                   NaN
# 3         4                       NaN                   NaN
# 4         5                       NaN                   NaN
# ...     ...                       ...                   ...
# 3069   3070              Supervisor 2      Prabhakar Myadam
# 3070   3071       Structural Engineer         Vishal Nalwar
# 3071   3072            Civil Engineer            ANIL PATIL
# 3072   3073                 Architect           ATUL PRABHU
# 3073   3074            Civil Engineer  RIYAZ AHMED KOTKUNDE
#
#                            ULB Name ULB Type
# 0       Akola Municipal Corporation        D
# 1            Akot Municipal Council        B
# 2      Murtizapur Municipal Council        C
# 3           Patur Municipal Council        C
# 4         Telhara Municipal Council        C
# ...                             ...      ...
# 3069  Solapur Municipal Corporation      NaN
# 3070  Solapur Municipal Corporation      NaN
# 3071  Solapur Municipal Corporation      NaN
# 3072  Solapur Municipal Corporation      NaN
# 3073  Solapur Municipal Corporation      NaN
#
# [9894 rows x 19 columns]

# %%
import sys
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import pie, axis, show
# %matplotlib inline                                                              

import warnings
warnings.filterwarnings('ignore') 
pd.set_option('display.max_columns', 100)
